# %%
# %run resources/library.py

# %% [markdown]
# # Notebook 3: Computing Convex Hulls Using `alphashape` - Part 2

# %% [markdown]
# ## What is `alphashape`?

# %% [markdown]
# `alphashape` is a Python package that can be used to generate a convex hull.

# %% [markdown]
# ## What is an $\alpha$ shape?

# %% [markdown]
# From [Wikipedia](https://en.wikipedia.org/wiki/Alpha_shape):
# > *In computational geometry, an alpha shape, or α-shape, is a family of piecewise linear simple curves in the Euclidean plane associated with the shape of a finite set of points. They were first defined by Edelsbrunner, Kirkpatrick & Seidel (1983). The alpha-shape associated with a set of points is a generalization of the concept of the convex hull, i.e. every convex hull is an alpha-shape but not every alpha shape is a convex hull.*

# %% [markdown]
# ## Load Cholera data

# %%
import pandas as pd

# %%
pumps_df = pd.read_csv('data/pumps.csv')

pumps_df
# Out:
#    FID       LON        LAT            Street
# 0  250 -0.136668  51.513341  Broadwick Street
# 1  251 -0.139586  51.513876     Kingly Street
# 2  252 -0.139671  51.514906   Ramillies Place
# 3  253 -0.131630  51.512354       Dean Street
# 4  254 -0.133594  51.512139     Rupert Street
# 5  255 -0.135919  51.511542       Bridle Lane
# 6  256 -0.133962  51.510019     Regent Street
# 7  257 -0.138199  51.511295    Warwick Street

# %%
deaths_df = pd.read_csv('data/cholera_deaths.csv')

deaths_df
# Out:
#      FID  DEATHS       LON        LAT
# 0      0       3 -0.137930  51.513418
# 1      1       2 -0.137883  51.513361
# 2      2       1 -0.137853  51.513317
# 3      3       1 -0.137812  51.513262
# 4      4       4 -0.137767  51.513204
# ..   ...     ...       ...        ...
# 245  245       3 -0.137108  51.514526
# 246  246       2 -0.137065  51.514706
# 247  247       1 -0.138474  51.512311
# 248  248       1 -0.138123  51.511998
# 249  249       1 -0.137762  51.511856
#
# [250 rows x 4 columns]

# %% [markdown]
# ## Create points lists from the pumps and deaths dataframes

# %%
import numpy as np

# %%
points_pumps = np.array([[lon,lat] for lat,lon in pumps_df[['LAT','LON']].values])

points_pumps
# Out:
# array([[-0.136668, 51.513341],
#        [-0.139586, 51.513876],
#        [-0.139671, 51.514906],
#        [-0.13163 , 51.512354],
#        [-0.133594, 51.512139],
#        [-0.135919, 51.511542],
#        [-0.133962, 51.510019],
#        [-0.138199, 51.511295]])

# %%
points_deaths = np.array([[lon,lat] for lat,lon in deaths_df[['LAT','LON']].values])

points_deaths
# Out:
# array([[-0.13793 , 51.513418],
#        [-0.137883, 51.513361],
#        [-0.137853, 51.513317],
#        [-0.137812, 51.513262],
#        [-0.137767, 51.513204],
#        [-0.137537, 51.513184],
#        [-0.1382  , 51.513359],
#        [-0.138045, 51.513328],
#        [-0.138276, 51.513323],
#        [-0.138223, 51.513427],
#        [-0.138337, 51.513381],
#        [-0.138563, 51.513462],
#        [-0.138426, 51.513216],
#        [-0.138378, 51.513169],
#        [-0.138337, 51.513116],
#        [-0.138645, 51.51324 ],
#        [-0.138698, 51.513164],
#        [-0.137924, 51.513178],
#        [-0.137865, 51.513111],
#        [-0.137811, 51.513055],
#        [-0.138762, 51.513441],
#        [-0.138799, 51.513592],
#        [-0.139045, 51.513402],
#        [-0.13897 , 51.51338 ],
#        [-0.138863, 51.513411],
#        [-0.138752, 51.513641],
#        [-0.138808, 51.513693],
#        [-0.138856, 51.513745],
#        [-0.138887, 51.513676],
#        [-0.139239, 51.51359 ],
#        [-0.139321, 51.513663],
#        [-0.139316, 51.513502],
#        [-0.139616, 51.513583],
#        [-0.139719, 51.513541],
#        [-0.140074, 51.513298],
#        [-0.139094, 51.513291],
#        [-0.139697, 51.513013],
#        [-0.139327, 51.512965],
#        [-0.139317, 51.512893],
#        [-0.139187, 51.512964],
#        [-0.139036, 51.513025],
#        [-0.139209, 51.513027],
#        [-0.138427, 51.512831],
#        [-0.138624, 51.512885],
#        [-0.138096, 51.512526],
#        [-0.138035, 51.512465],
#        [-0.137984, 51.512428],
#        [-0.138065, 51.512415],
#        [-0.138194, 51.51251 ],
#        [-0.137818, 51.512378],
#        [-0.137656, 51.512447],
#        [-0.137584, 51.512491],
#        [-0.13765 , 51.512374],
#        [-0.13745 , 51.512339],
#        [-0.137376, 51.512364],
#        [-0.137327, 51.512319],
#        [-0.13698 , 51.51254 ],
#        [-0.13718 , 51.512649],
#        [-0.137052, 51.512692],
#        [-0.137695, 51.512957],
#        [-0.137533, 51.512765],
#        [-0.137419, 51.51278 ],
#        [-0.137368, 51.512726],
#        [-0.137325, 51.512681],
#        [-0.137531, 51.512914],
#        [-0.137562, 51.513046],
#        [-0.137466, 51.513074],
#        [-0.137386, 51.513087],
#        [-0.137306, 51.513122],
#        [-0.137089, 51.513187],
#        [-0.136996, 51.513214],
#        [-0.136859, 51.513249],
#        [-0.136778, 51.513271],
#        [-0.136705, 51.5133  ],
#        [-0.136493, 51.51316 ],
#        [-0.13633 , 51.513016],
#        [-0.136424, 51.512921],
#        [-0.136523, 51.51289 ],
#        [-0.136599, 51.512859],
#        [-0.136699, 51.51283 ],
#        [-0.136819, 51.512782],
#        [-0.136973, 51.512729],
#        [-0.136358, 51.512868],
#        [-0.13663 , 51.512723],
#        [-0.136584, 51.512654],
#        [-0.136423, 51.512713],
#        [-0.136345, 51.512615],
#        [-0.136437, 51.512491],
#        [-0.136377, 51.512449],
#        [-0.136197, 51.512465],
#        [-0.136142, 51.512413],
#        [-0.136102, 51.512358],
#        [-0.13603 , 51.512271],
#        [-0.13631 , 51.512355],
#        [-0.13594 , 51.511991],
#        [-0.135858, 51.512083],
#        [-0.1358  , 51.512031],
#        [-0.135717, 51.51197 ],
#        [-0.135119, 51.511882],
#        [-0.135144, 51.51205 ],
#        [-0.135394, 51.51225 ],
#        [-0.135409, 51.512162],
#        [-0.135472, 51.512212],
#        [-0.135765, 51.512573],
#        [-0.135871, 51.512575],
#        [-0.135976, 51.512672],
#        [-0.136033, 51.512727],
#        [-0.136115, 51.512794],
#        [-0.13618 , 51.512846],
#        [-0.136083, 51.512879],
#        [-0.136139, 51.512939],
#        [-0.135329, 51.512765],
#        [-0.135122, 51.512844],
#        [-0.134645, 51.512532],
#        [-0.134522, 51.512198],
#        [-0.134967, 51.512215],
#        [-0.135098, 51.513154],
#        [-0.134394, 51.513056],
#        [-0.134505, 51.513165],
#        [-0.134437, 51.513098],
#        [-0.134594, 51.513238],
#        [-0.13464 , 51.513293],
#        [-0.134709, 51.513379],
#        [-0.134756, 51.513431],
#        [-0.135244, 51.513475],
#        [-0.134897, 51.513422],
#        [-0.135158, 51.513528],
#        [-0.135344, 51.513481],
#        [-0.135063, 51.513594],
#        [-0.135801, 51.513227],
#        [-0.135762, 51.51318 ],
#        [-0.13574 , 51.513132],
#        [-0.135645, 51.513048],
#        [-0.135602, 51.513006],
#        [-0.135501, 51.512883],
#        [-0.135832, 51.51327 ],
#        [-0.136049, 51.513459],
#        [-0.13614 , 51.513431],
#        [-0.136228, 51.513402],
#        [-0.134999, 51.512593],
#        [-0.134793, 51.512585],
#        [-0.134896, 51.512555],
#        [-0.135   , 51.512521],
#        [-0.133483, 51.513137],
#        [-0.133265, 51.513228],
#        [-0.133296, 51.513152],
#        [-0.132933, 51.513258],
#        [-0.133998, 51.513544],
#        [-0.134042, 51.513626],
#        [-0.134156, 51.513637],
#        [-0.134091, 51.513524],
#        [-0.134272, 51.51382 ],
#        [-0.13422 , 51.513724],
#        [-0.134704, 51.513704],
#        [-0.134782, 51.513831],
#        [-0.13501 , 51.513915],
#        [-0.134923, 51.513597],
#        [-0.134885, 51.514032],
#        [-0.134212, 51.513891],
#        [-0.134135, 51.513758],
#        [-0.134364, 51.514065],
#        [-0.134447, 51.514146],
#        [-0.134479, 51.514201],
#        [-0.134658, 51.51423 ],
#        [-0.134367, 51.514319],
#        [-0.134179, 51.514377],
#        [-0.13416 , 51.514357],
#        [-0.134069, 51.514382],
#        [-0.134085, 51.514402],
#        [-0.133821, 51.514522],
#        [-0.133922, 51.514497],
#        [-0.13385 , 51.514472],
#        [-0.133725, 51.514504],
#        [-0.133745, 51.514546],
#        [-0.133676, 51.514561],
#        [-0.133563, 51.514594],
#        [-0.133467, 51.514581],
#        [-0.133393, 51.514606],
#        [-0.134474, 51.515834],
#        [-0.135259, 51.515195],
#        [-0.135395, 51.515149],
#        [-0.136022, 51.514818],
#        [-0.136804, 51.514843],
#        [-0.136583, 51.514914],
#        [-0.135653, 51.514496],
#        [-0.135578, 51.514743],
#        [-0.13486 , 51.514467],
#        [-0.13469 , 51.514453],
#        [-0.134818, 51.514845],
#        [-0.135704, 51.514389],
#        [-0.135561, 51.514399],
#        [-0.135649, 51.514335],
#        [-0.135415, 51.514224],
#        [-0.135576, 51.51422 ],
#        [-0.135357, 51.514145],
#        [-0.135475, 51.514108],
#        [-0.136226, 51.514359],
#        [-0.136328, 51.514326],
#        [-0.136222, 51.514544],
#        [-0.136117, 51.514569],
#        [-0.13603 , 51.514586],
#        [-0.136266, 51.514612],
#        [-0.136421, 51.514575],
#        [-0.136935, 51.514507],
#        [-0.136931, 51.514274],
#        [-0.136799, 51.514293],
#        [-0.13678 , 51.514058],
#        [-0.136696, 51.514148],
#        [-0.136712, 51.513961],
#        [-0.136123, 51.514027],
#        [-0.135958, 51.514076],
#        [-0.135883, 51.514096],
#        [-0.135788, 51.514134],
#        [-0.135849, 51.514033],
#        [-0.136008, 51.513996],
#        [-0.136099, 51.51396 ],
#        [-0.13617 , 51.513945],
#        [-0.135485, 51.513821],
#        [-0.135374, 51.513999],
#        [-0.135582, 51.513795],
#        [-0.135679, 51.513766],
#        [-0.135814, 51.513726],
#        [-0.135905, 51.513692],
#        [-0.135992, 51.513672],
#        [-0.136217, 51.513603],
#        [-0.136579, 51.513482],
#        [-0.136675, 51.513458],
#        [-0.136764, 51.513429],
#        [-0.136877, 51.513404],
#        [-0.136953, 51.513359],
#        [-0.13723 , 51.513378],
#        [-0.136651, 51.513855],
#        [-0.136503, 51.513875],
#        [-0.137367, 51.513565],
#        [-0.137422, 51.513616],
#        [-0.137472, 51.513742],
#        [-0.1383  , 51.513918],
#        [-0.137363, 51.513772],
#        [-0.137995, 51.513502],
#        [-0.138139, 51.513712],
#        [-0.138239, 51.513644],
#        [-0.138272, 51.513711],
#        [-0.138083, 51.514061],
#        [-0.137912, 51.514748],
#        [-0.137707, 51.514794],
#        [-0.137108, 51.514526],
#        [-0.137065, 51.514706],
#        [-0.138474, 51.512311],
#        [-0.138123, 51.511998],
#        [-0.137762, 51.511856]])

# %% [markdown]
# ## Combine all the points to generate the alpha shape

# %%
points = np.concatenate((points_pumps, points_deaths), axis=0)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Display all points

# %%
fig, ax = plt.subplots()
ax.scatter(*zip(*points))
plt.show()

# %% [markdown]
# ## Generate the alpha shape using combined points

# %%
import alphashape

# %%
alpha_shape = alphashape.alphashape(points, 0.)

type(alpha_shape)
# Out:
# shapely.geometry.polygon.Polygon

# %%
alpha_shape
# Out:
# <POLYGON ((-0.134 51.51, -0.138 51.511, -0.14 51.513, -0.14 51.515, -0.134 5...>

# %%
from descartes import PolygonPatch

# %%
fig, ax = plt.subplots()
ax.scatter(*zip(*points))
ax.add_patch(PolygonPatch(alpha_shape, alpha=0.2))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 fig, ax = plt.subplots()
#       2 ax.scatter(*zip(*points))
# ----> 3 ax.add_patch(PolygonPatch(alpha_shape, alpha=0.2))
#       4 plt.show()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/voronoi/lib/python3.10/site-packages/descartes/patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/voronoi/lib/python3.10/site-packages/descartes/patch.py:62, in PolygonPath(polygon)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
# ---> 62 vertices = concatenate([
#      63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/voronoi/lib/python3.10/site-packages/descartes/patch.py:63, in <listcomp>(.0)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
#      62 vertices = concatenate([
# ---> 63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed

# %% [markdown]
# ## Use the Polygon `buffer()` function to expand the alpha shape boundary

# %%
alpha_shape = alphashape.alphashape(points, 2.0).buffer(0.002)

type(alpha_shape)
# Out:
# shapely.geometry.polygon.Polygon

# %%
fig, ax = plt.subplots()
ax.scatter(*zip(*points))
ax.add_patch(PolygonPatch(alpha_shape, alpha=0.2))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 fig, ax = plt.subplots()
#       2 ax.scatter(*zip(*points))
# ----> 3 ax.add_patch(PolygonPatch(alpha_shape, alpha=0.2))
#       4 plt.show()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/voronoi/lib/python3.10/site-packages/descartes/patch.py:87, in PolygonPatch(polygon, **kwargs)
#      73 def PolygonPatch(polygon, **kwargs):
#      74     """Constructs a matplotlib patch from a geometric object
#      75
#      76     The `polygon` may be a Shapely or GeoJSON-like object with or without holes.
#    (...)
#      85
#      86     """
# ---> 87     return PathPatch(PolygonPath(polygon), **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/voronoi/lib/python3.10/site-packages/descartes/patch.py:62, in PolygonPath(polygon)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
# ---> 62 vertices = concatenate([
#      63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/voronoi/lib/python3.10/site-packages/descartes/patch.py:63, in <listcomp>(.0)
#      58     else:
#      59         raise ValueError(
#      60             "A polygon or multi-polygon representation is required")
#      62 vertices = concatenate([
# ---> 63     concatenate([asarray(t.exterior)[:, :2]] +
#      64                 [asarray(r)[:, :2] for r in t.interiors])
#      65     for t in polygon])
#      66 codes = concatenate([
#      67     concatenate([coding(t.exterior)] +
#      68                 [coding(r) for r in t.interiors]) for t in polygon])
#      70 return Path(vertices, codes)
#
# IndexError: too many indices for array: array is 0-dimensional, but 2 were indexed

# %% [markdown]
# ## Plot the convex hull polygon generated using `alphashape`

# %% [markdown]
# The code below can be used to generate a Geopandas geodataframe to hold the convex hull geometry.

# %%
x,y = alpha_shape.exterior.xy

plt.plot(x, y, color='#6699cc', alpha=0.7,
    linewidth=3, solid_capstyle='round', zorder=2)

# %% [markdown]
# ## References

# %% [markdown]
# 1. Alphashape Reference: https://github.com/bellockk/alphashape
